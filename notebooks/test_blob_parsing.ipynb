# %% [markdown]
# ### This notebook is to test out elt/etl for reading through all the pdf tarfiles for arxiv and converting them to raw searchable pdfs and then converting that to our training data via pdfplumber

# %% [markdown]
# PDFPlumber is used to extract the bounding boxes for characters and words from each pdf and saved as csv.
# PDF2Image is then used to save the pdf as .png images. PDF2Image requires the use of conda to install poppler
# 1. conda create -n pdf python=3.7
# 2. conda activate pdf
# 3. conda install -c conda-forge poppler
# 4. pip install pdf2image

# %% [markdown]
# ### TO DO
# 1. convert the following functions into @ray.remote
#     2. unzip tars for a given year
#     3. move pdf in each unzipped folder to blob
#     4. delete pdfs from local

# %%
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from pathlib import Path
import shutil
import time
import glob
import pdfplumber
import pandas as pd
from pdf2image import convert_from_path
from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)
import ray
import tarfile
from retry import retry
import sys
import os

'''
For ray to work all the files and modules have to be within the original sys.path.
for some reason you can't append another path and import files from there. Therefore
have to set the PYTHONPATH for each new process. In this case the run_pdfplumber
function is calling src.fixunicode which is in another child directory
'''
os.environ['PYTHONPATH'] = os.path.dirname(os.getcwd())
sys.path.append(os.path.dirname(os.getcwd()))
import config
import src.blob_data_transfer as blob_pull
import src.fixunicode as fixunicode

# %%
os.getcwd()
# Out:
# '/home/arxiv/doc_intel_etl/notebooks'

# %%
# ray.shutdown()
ray.init()
# Out:
# 2020-07-08 04:54:18,424	INFO resource_spec.py:212 -- Starting Ray with 10.89 GiB memory available for workers and up to 5.45 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-07-08 04:54:18,743	INFO services.py:1170 -- View the Ray dashboard at localhost:8265
# 2020-07-08 04:54:18,749	WARNING services.py:1494 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This may slow down performance! You may be able to free up space by deleting files in /dev/shm or terminating any running plasma_store_server processes. If you are inside a Docker container, you may need to pass an argument with the flag '--shm-size' to 'docker run'.
# {'node_ip_address': '172.17.0.2',
#  'raylet_ip_address': '172.17.0.2',
#  'redis_address': '172.17.0.2:32002',
#  'object_store_address': '/tmp/ray/session_2020-07-08_04-54-18_422911_51649/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-07-08_04-54-18_422911_51649/sockets/raylet',
#  'webui_url': 'localhost:8265',
#  'session_dir': '/tmp/ray/session_2020-07-08_04-54-18_422911_51649'}
# 2020-07-08 04:54:19,680	WARNING worker.py:1090 -- The dashboard on node bc572e8fa404 failed with the following error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ray/dashboard/dashboard.py", line 1220, in <module>
#     dashboard.run()
#   File "/opt/conda/lib/python3.7/site-packages/ray/dashboard/dashboard.py", line 594, in run
#     aiohttp.web.run_app(self.app, host=self.host, port=self.port)
#   File "/opt/conda/lib/python3.7/site-packages/aiohttp/web.py", line 433, in run_app
#     reuse_port=reuse_port))
#   File "/opt/conda/lib/python3.7/asyncio/base_events.py", line 587, in run_until_complete
#     return future.result()
#   File "/opt/conda/lib/python3.7/site-packages/aiohttp/web.py", line 359, in _run_app
#     await site.start()
#   File "/opt/conda/lib/python3.7/site-packages/aiohttp/web_runner.py", line 104, in start
#     reuse_port=self._reuse_port)
#   File "/opt/conda/lib/python3.7/asyncio/base_events.py", line 1389, in create_server
#     % (sa, err.strerror.lower())) from None
# OSError: [Errno 99] error while attempting to bind on address ('::1', 8265, 0, 0): cannot assign requested address

# %%
# credentials for blob with our raw data
storage_name = config.azure_blob['storage_name']
key = config.azure_blob['key']
connect_str = config.azure_blob['connect_str']

# %%
CONTAINER = config.azure_blob['container']
file_type = 'tar'
year_del = 2
prefix = 'arxiv_dl/pdf'

# %% [markdown]
# # TODO
# 1. Need to add a try and exception handling for "unzip_tar"
# 2. Add proper logging

# %% [markdown]
# Data is in the following format:  arxiv_dl/pdf/year/tar_file in the raw data directory
# We need to do the following:
# Class variables:
# 1. full_blob_list
# 2. blob_service_client
# 3. CONTAINER
# 4.

# %%
@ray.remote
def unzip_tar(file, tar_path, extract_path):
    
    while not os.path.exists(os.path.join(tar_path, file)):
        time.sleep(0.5)
    if os.path.isfile(os.path.join(tar_path, file)):
        # Can't open empty tar files becuase it produces a read error so need to make sure
        # tar file isn't empty
        try:
            tar = tarfile.open(os.path.join(tar_path, file))
            tar.extractall(path = extract_path)
            tar.close()
        except Exception as e:
            print("Can't open because it's empty: ", file)
    else:
        raise ValueError("%s isn't a file yet" % os.path.join(tar_path, file))

@ray.remote
def move_pdf_to_blob(filepath):
    # Create a blob client using the local file name as the name for the blob
    if filepath is not None:
        pdf_blob_path = filepath.split('/')[0]+'/'+filepath.split('/')[1]+'/'+filepath.split('/')[-1]
        blob_client = blob_service_client.get_blob_client(container=CONTAINER, blob=pdf_blob_path)
        with open(filepath, "rb") as pdf:
            blob_client.upload_blob(pdf)

@retry(tries=10, delay=1)
def open_pdf(filepath):
    try:
        with pdfplumber.open(filepath) as pdf:
            chars = []
            words = []
            text = ""
            for page in range(len(pdf.pages)):
                current_page = pdf.pages[page]
                chars.extend(current_page.chars)
                words.extend(current_page.extract_words(x_tolerance=1, y_tolerance=0))
                text += current_page.extract_text(x_tolerance=1, y_tolerance=0)
        
        # run text through very basic unicode normalization routines before sending back
        text = fixunicode.fix_unicode(text)
        
        return chars, words, text
    except Exception as e:
        print("Error: can't open ", filepath)
        
@ray.remote
def run_pdfplumber(filepath, char_path, word_path, text_path):
    filename = filepath.split('/')[-1]
    
    while not os.path.exists(filepath):
        time.sleep(0.5)
    try:
        chars, words, text = open_pdf(filepath)
        chars_df = pd.DataFrame(chars)
        chars_df.to_csv(char_path+'/'+filename.replace('.pdf','')+'_chars.csv', index=False)   
        words_df = pd.DataFrame(words)
        words_df.to_csv(word_path+'/'+filename.replace('.pdf','')+'_words.csv', index=False)
        
        # write full pdf text to csv
        f = open(text_path+'/'+filename.replace('.pdf','')+'.txt', 'w')
        f.write(text)
        f.close()
        
        return filepath
    except Exception as e:
        print("Can't unpack: ", filepath)
        os.remove(filepath)
    

@ray.remote
def move_csv_to_blob(csv):
    if csv is not None:
        csv_blob_path = '/'.join(csv.split('/')[:4])+'/'+csv.split('/')[-1]
        blob_client = blob_service_client.get_blob_client(container=CONTAINER, blob=csv_blob_path)
        with open(csv, "rb") as csv:
            blob_client.upload_blob(csv)

@ray.remote
def convert_to_image(filepath, image_path):
    if os.path.exists(filepath):
        year = filepath.split('/')[1]
        pdf_name = filepath.split('/')[-1]
        image_list = []
        try:
            images = convert_from_path(filepath)
            for i, image in enumerate(images):
                fname = image_path+"/"+pdf_name.replace('.pdf','')+"_"+str(i)+".png"
                image.save(fname, "PNG")
                image_list.extend(fname)
            return image_list
        except Exception as e:
            print("{} can't be converted to image".format(filepath))
    
@ray.remote
def move_image_to_blob(img):
    if img is not None:
        img_blob_path = '/'.join(img.split('/')[:3])+'/'+img.split('/')[-1]
        blob_client = blob_service_client.get_blob_client(container=CONTAINER, blob=img_blob_path)
        with open(img, "rb") as img:
            blob_client.upload_blob(img)

@ray.remote
def move_txt_to_blob(txt):
    if txt is not None:
        txt_blob_path = '/'.join(txt.split('/')[:4])+'/'+txt.split('/')[-1]
        blob_client = blob_service_client.get_blob_client(container=CONTAINER, blob=txt_blob_path)
        with open(txt, "rb") as txt:
            blob_client.upload_blob(txt)

# %%
full_blob_list = blob_pull.get_blob_list(prefix)
pdf_tar_list, year_list = blob_pull.get_blob_file_list(file_type, full_blob_list, year_del)
year_list = ['1991']
year = year_list[0]
# for year in year_list:
tar_path = blob_pull.copy_blob(year, pdf_tar_list, year_del)

extract_path = 'arxiv_pdf/'+year
Path(extract_path).mkdir(parents=True, exist_ok=True)

pdfplumber_path = 'arxiv_training_data/pdfplumber'

char_path = pdfplumber_path+'/chars/'+year
Path(char_path).mkdir(parents=True, exist_ok=True)

word_path = pdfplumber_path+'/words/'+year
Path(word_path).mkdir(parents=True, exist_ok=True)

text_path = pdfplumber_path+'/text/'+year
Path(text_path).mkdir(parents=True, exist_ok=True)

image_path = "arxiv_training_data/pdf_images/"+year
Path(image_path).mkdir(parents=True, exist_ok=True)
    
    # work on all the pdfs for a given year. Each work item is parallized through ray to
    # go through all the pdfs. Work items are run sequentally so we don't run into any io
    # issues
#         plumbed_pdf_list = ray.get([run_pdfplumber.remote(pdf, char_path, word_path, text_path) for pdf in pdf_list])
#         print("Finished pdfplumber for year: ", year)
    
#         ray.get([move_pdf_to_blob.remote(pdf) for pdf in plumbed_pdf_list])
#         print("Moved pdfs to blob")
#         csv_list = []
#         csv_list.extend(glob.glob(word_path+'/*.csv'))
#         csv_list.extend(glob.glob(char_path+'/*.csv'))
#         ray.get([move_csv_to_blob.remote(csv) for csv in csv_list])
#         print("Moved csvs to blob for year: ", year)
#         image_list = []
#         image_list.extend(glob.glob(image_path+'/*.png'))
#         ray.get([move_image_to_blob.remote(img) for img in image_list])
#         print("Moved images to blob")
#         text_list = []
#         text_list.extend(glob.glob(text_path+'/*.txt'))
#         ray.get([move_txt_to_blob.remote(txt) for txt in text_list])
#         print("Moved text files to blob")

#         # delete all the paths and files we saved on local
#         time.sleep(30)
#         shutil.rmtree('arxiv_pdf')
#         shutil.rmtree('arxiv_dl')
#         shutil.rmtree('arxiv_training_data')

# %%
# extract all the tar files for a given year
# ray.get([unzip_tar.remote(file, tar_path, extract_path) for file in os.listdir(tar_path)])
# print("Finished unzipping {} tar files".format(len(os.listdir(tar_path))))

# get list of all pdfs for the year that have been extracted
sub_folders = os.listdir(extract_path)
pdf_list = []
for folder in sub_folders:
    pdf_list.extend(glob.glob(extract_path+'/'+folder+'/*.pdf'))

# %%
ray.get([convert_to_image.remote(pdf, image_path) for pdf in pdf_list])
# Out:
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111006.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111056.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111009.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111007.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111037.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111020.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111019.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111002.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9111/hep-th9111048.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111021.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111057.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111044.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111027.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111011.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111064.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111026.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111033.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111024.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111040.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111051.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111018.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9111/hep-th9111017.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111023.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111010.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111039.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111034.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9111/hep-th9111046.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111005.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111013.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111035.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111036.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9111/hep-th9111022.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9111/hep-th9111053.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9111/hep-th9111059.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9111/hep-th9111049.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9111/hep-th9111031.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9111/hep-th9111060.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111004.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111047.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111015.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111001.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9111/hep-th9111054.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9108/hep-th9108008.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9111/hep-th9111028.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9111/hep-th9111038.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9111/hep-th9111030.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9111/hep-th9111062.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111032.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111012.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111052.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111029.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9111/hep-th9111003.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9108/hep-th9108024.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111014.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111041.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111058.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111008.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9111/hep-th9111043.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9108/hep-th9108006.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9108/hep-th9108014.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9111/hep-th9111061.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9111/hep-th9111025.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9111/hep-th9111063.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9111/hep-th9111016.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9111/hep-th9111055.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9108/hep-th9108021.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9108/hep-th9108023.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9111/hep-th9111045.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9108/hep-th9108027.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9108/hep-th9108005.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9108/hep-th9108002.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9108/hep-th9108013.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110071.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110032.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110037.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9108/hep-th9108018.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9108/hep-th9108025.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110040.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110008.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110042.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9108/hep-th9108011.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9108/hep-th9108001.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110019.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110057.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9108/hep-th9108009.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9108/hep-th9108022.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110063.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110028.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110023.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9108/hep-th9108010.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9108/hep-th9108016.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9110/hep-th9110001.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9110/hep-th9110041.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9108/hep-th9108028.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9108/hep-th9108007.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9108/hep-th9108003.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110051.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110054.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9108/hep-th9108004.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9108/hep-th9108019.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9108/hep-th9108015.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110070.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110074.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110044.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9108/hep-th9108026.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9108/hep-th9108020.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9108/hep-th9108017.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110003.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110007.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110006.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110016.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110043.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110045.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110014.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110030.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110046.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110038.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110064.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110029.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110027.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110065.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110059.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110075.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110012.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110035.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110005.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110017.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110049.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110034.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110072.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110009.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110036.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110026.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110055.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9110/hep-th9110056.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9110/hep-th9110076.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9110/hep-th9110061.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110033.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110058.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110052.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110015.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110048.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110018.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110069.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110002.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110004.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110031.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110025.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110021.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110010.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110011.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110060.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110062.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110073.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9110/hep-th9110047.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9110/hep-th9110066.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109046.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109011.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109029.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109042.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109006.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109025.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9110/hep-th9110013.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109028.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109007.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109023.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109045.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109001.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9110/hep-th9110022.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9109/hep-th9109053.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9109/hep-th9109035.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9109/hep-th9109013.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9109/hep-th9109040.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9110/hep-th9110039.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9109/hep-th9109033.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9109/hep-th9109004.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9109/hep-th9109022.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9110/hep-th9110053.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9109/hep-th9109031.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9109/hep-th9109032.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9109/hep-th9109020.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9109/hep-th9109052.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9110/hep-th9110067.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9109/hep-th9109014.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9109/hep-th9109050.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9109/hep-th9109054.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9109/hep-th9109051.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9109/hep-th9109008.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9110/hep-th9110020.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9109/hep-th9109021.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9109/hep-th9109036.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9109/hep-th9109030.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9109/hep-th9109038.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9109/hep-th9109012.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9109/hep-th9109003.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9109/hep-th9109049.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9109/hep-th9109048.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109047.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9109/hep-th9109027.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112063.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112036.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112010.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109019.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109005.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9109/hep-th9109056.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112041.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112056.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9109/hep-th9109055.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9109/hep-th9109034.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9109/hep-th9109024.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112011.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112065.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112014.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112059.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9109/hep-th9109015.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9109/hep-th9109041.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9109/hep-th9109057.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112021.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112028.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112050.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9109/hep-th9109017.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9109/hep-th9109010.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9109/hep-th9109058.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112044.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112048.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112013.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9109/hep-th9109002.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9109/hep-th9109026.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112025.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112029.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112068.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112047.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9109/hep-th9109016.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9109/hep-th9109044.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9112/hep-th9112023.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9109/hep-th9109009.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9109/hep-th9109018.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9109/hep-th9109037.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112053.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112017.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112022.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112072.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112004.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112012.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112046.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112069.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112019.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112039.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9112/hep-th9112051.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112027.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112031.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112033.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112038.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112006.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112009.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112001.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112034.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112060.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112008.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112075.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112058.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112020.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112062.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112007.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112049.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112040.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112076.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112055.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-th9112035.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112015.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112064.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112061.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112066.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112054.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9112/hep-th9112018.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9112/hep-th9112045.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9112/hep-th9112032.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9112/hep-th9112024.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112074.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112037.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112002.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112026.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112071.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112016.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112067.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-lat9112002.pdf can't be converted to image
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
# (pid=51698) arxiv_pdf/1991/9112/hep-th9112057.pdf can't be converted to image
# (pid=51698) arxiv_pdf/1991/9107/hep-lat9107001.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112070.pdf can't be converted to image
# (pid=51700) arxiv_pdf/1991/9112/hep-th9112003.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112073.pdf can't be converted to image
# (pid=51699) arxiv_pdf/1991/9112/hep-th9112042.pdf can't be converted to image
# (pid=51697) arxiv_pdf/1991/9112/hep-th9112043.pdf can't be converted to image
# (pid=51696) arxiv_pdf/1991/9112/hep-lat9112001.pdf can't be converted to image
# (pid=51694) arxiv_pdf/1991/9112/hep-th9112030.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9112/hep-th9112005.pdf can't be converted to image
# (pid=51695) arxiv_pdf/1991/9107/hep-lat9107002.pdf can't be converted to image
# (pid=51693) arxiv_pdf/1991/9112/hep-th9112052.pdf can't be converted to image

# %%
def get_list(path, file_type):
    return glob.glob(path+file_type, recursive=True)

# %%
csv_list = get_list(pdfplumber_path, 'word/*.csv')
len(csv_list)
# Out:
# 0

# %%
import src.blob_data_transfer as blob_pull

# %%
[blob_pull.send_to_blob(txt, 4) for txt in text_list[:10]]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
file = text_list[1]
split=4
file_blob_path = '/'.join(file.split('/')[:split])+'/'+file.split('/')[-1]
print(file_blob_path)
# blob_client = blob_service_client.get_blob_client(container=CONTAINER, blob=file_blob_path)
# with open(file, "rb") as f:
#     blob_client.upload_blob(f, overwrite=True)
# Out:
# arxiv_training_data/pdfplumber/text/1991/pdfplumber

# %%
pdfplumber_path
# Out:
# 'arxiv_training_data/pdfplumber'
